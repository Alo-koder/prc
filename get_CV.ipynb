# %%
import eclabfiles as ecf
import numpy as np
from matplotlib import pyplot as plt

# %%
date='24 X'

# %%
filenames   = {
    '24 X': 'T:\\Team\\Szewczyk\\Data\\20231024\\raw\\A00100_C01.mpr',
    }

# %%
def read_data(filename=filenames[date]):
    
    raw_data = ecf.to_df(filename)
    
    # Renaming columns
    col_dict = {'time': 't', 'Ewe': 'V', '<I>': 'I'}
    data = raw_data.rename(columns = col_dict)

    return data

data = read_data()

# %%
data
# Out:
#                  t  control_V         V         I  cycle number    (Q-Qo)  \
# 0         0.000000  -0.933293 -0.933708  0.016302           1.0  0.000000
# 1         0.082500  -0.931644 -0.932216  0.014249           1.0  0.000001
# 2         0.232500  -0.928645 -0.929096  0.014654           1.0  0.000003
# 3         0.382300  -0.925647 -0.926146  0.013954           1.0  0.000005
# 4         0.532300  -0.922649 -0.923121  0.013707           1.0  0.000008
# ...            ...        ...       ...       ...           ...       ...
# 32396  4854.311187   0.154691  0.154612  0.088534           9.0  0.413424
# 32397  4854.461087   0.157690  0.157593  0.088538           9.0  0.413437
# 32398  4854.610987   0.160688  0.160639  0.088780           9.0  0.413450
# 32399  4854.723487   0.162937  0.162904  0.088975           9.0  0.413460
# 32400  4854.754287   0.163836  0.163737  0.088662           9.0  0.413463
#
#        I Range  mode  ox/red  error  control changes  counter inc.  \
# 0           38     2       1      0                0             0
# 1           38     2       1      0                1             0
# 2           38     2       1      0                1             0
# 3           38     2       1      0                1             0
# 4           38     2       1      0                1             0
# ...        ...   ...     ...    ...              ...           ...
# 32396       38     2       1      0                1             0
# 32397       38     2       1      0                1             0
# 32398       38     2       1      0                1             0
# 32399       38     2       1      0                1             0
# 32400       38     2       1      0                0             0
#
#                 uts
# 0      1.698139e+09
# 1      1.698139e+09
# 2      1.698139e+09
# 3      1.698139e+09
# 4      1.698139e+09
# ...             ...
# 32396  1.698144e+09
# 32397  1.698144e+09
# 32398  1.698144e+09
# 32399  1.698144e+09
# 32400  1.698144e+09
#
# [32401 rows x 13 columns]

# %%
def get_CV(data=data):

    voltage = np.array(data['V'])
    current = np.array(data['I'])
    # time = np.array(data['t'])

    fig, ax = plt.subplots()
    plt.title(f'CV {date}')
    plt.xlabel('Voltage')
    plt.ylabel('I [check the unit]')
    # plt.scatter(voltage, current, c=time, s=0.2)
    plt.plot(voltage, current)

get_CV(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 14
#      11     plt.colorbar(fig)
#      12     plt.scatter(voltage, current, c=time, s=0.2)
# ---> 14 get_CV(data)
#
# Cell In[39], line 11, in get_CV(data)
#       9 plt.xlabel('Voltage')
#      10 plt.ylabel('I [check the unit]')
# ---> 11 plt.colorbar(fig)
#      12 plt.scatter(voltage, current, c=time, s=0.2)
#
# File c:\Users\go68nim\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2326, in colorbar(mappable, cax, ax, **kwargs)
#    2321     if mappable is None:
#    2322         raise RuntimeError('No mappable was found to use for colorbar '
#    2323                            'creation. First define a mappable such as '
#    2324                            'an image (with imshow) or a contour set ('
#    2325                            'with contourf).')
# -> 2326 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2327 return ret
#
# File c:\Users\go68nim\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\figure.py:1310, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1306     cax.grid(visible=False, which='both', axis='both')
#    1308 NON_COLORBAR_KEYS = [  # remove kws that cannot be passed to Colorbar
#    1309     'fraction', 'pad', 'shrink', 'aspect', 'anchor', 'panchor']
# -> 1310 cb = cbar.Colorbar(cax, mappable, **{
#    1311     k: v for k, v in kwargs.items() if k not in NON_COLORBAR_KEYS})
#    1312 cax.figure.stale = True
#    1313 return cb
#
# File c:\Users\go68nim\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\colorbar.py:302, in Colorbar.__init__(self, ax, mappable, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, extendfrac, extendrect, label, location)
#     299     mappable = cm.ScalarMappable(norm=norm, cmap=cmap)
#     301 self.mappable = mappable
# --> 302 cmap = mappable.cmap
#     303 norm = mappable.norm
#     305 filled = True
#
# AttributeError: 'Figure' object has no attribute 'cmap'
